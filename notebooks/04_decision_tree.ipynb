# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/Telco_Churn_Cleaned.csv")
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
# 3          No              No        One year               No
# 4          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn  tenure_group  \
# 0           Electronic check          29.85        29.85      0         0-1yr
# 1               Mailed check          56.95      1889.50      0         2-4yr
# 2               Mailed check          53.85       108.15      1         0-1yr
# 3  Bank transfer (automatic)          42.30      1840.75      0         2-4yr
# 4           Electronic check          70.70       151.65      1         0-1yr
#
#    num_services
# 0             1
# 1             2
# 2             2
# 3             3
# 4             0
#
# [5 rows x 22 columns]

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  tenure_group  \
# 0           Electronic check          29.85         29.85         0-1yr
# 1               Mailed check          56.95       1889.50         2-4yr
# 2               Mailed check          53.85        108.15         0-1yr
# 3  Bank transfer (automatic)          42.30       1840.75         2-4yr
# 4           Electronic check          70.70        151.65         0-1yr
#
#   num_services
# 0            1
# 1            2
# 2            2
# 3            3
# 4            0
#
# [5 rows x 21 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y,test_size=0.2,stratify=y,random_state=42)

# %%
import joblib
preprocessor = joblib.load("../models/preprocessor.pkl")

X_train_p = preprocessor.transform(X_train)
X_test_p = preprocessor.transform(X_test)

# %%
feature_names = preprocessor.get_feature_names_out()

# Convert to DataFrame
X_train_processed = pd.DataFrame(
    X_train_p,
    columns=feature_names,
    index=X_train.index
)

X_test_processed = pd.DataFrame(
    X_test_p,
    columns=feature_names,
    index=X_test.index
)
X_train_processed.head()
# Out:
#       cat__gender_Female  cat__gender_Male  cat__Partner_No  cat__Partner_Yes  \
# 3738                 0.0               1.0              1.0               0.0
# 3151                 0.0               1.0              0.0               1.0
# 4860                 0.0               1.0              0.0               1.0
# 3867                 1.0               0.0              0.0               1.0
# 3810                 0.0               1.0              0.0               1.0
#
#       cat__Dependents_No  cat__Dependents_Yes  cat__PhoneService_No  \
# 3738                 1.0                  0.0                   1.0
# 3151                 0.0                  1.0                   0.0
# 4860                 0.0                  1.0                   1.0
# 3867                 1.0                  0.0                   0.0
# 3810                 0.0                  1.0                   0.0
#
#       cat__PhoneService_Yes  cat__MultipleLines_No  \
# 3738                    0.0                    0.0
# 3151                    1.0                    1.0
# 4860                    0.0                    0.0
# 3867                    1.0                    1.0
# 3810                    1.0                    1.0
#
#       cat__MultipleLines_No phone service  ...  cat__tenure_group_0-1yr  \
# 3738                                  1.0  ...                      0.0
# 3151                                  0.0  ...                      0.0
# 4860                                  1.0  ...                      0.0
# 3867                                  0.0  ...                      0.0
# 3810                                  0.0  ...                      1.0
#
#       cat__tenure_group_1-2yr  cat__tenure_group_2-4yr  \
# 3738                      0.0                      1.0
# 3151                      1.0                      0.0
# 4860                      1.0                      0.0
# 3867                      0.0                      1.0
# 3810                      0.0                      0.0
#
#       cat__tenure_group_4-6yr  cat__tenure_group_nan  \
# 3738                      0.0                    0.0
# 3151                      0.0                    0.0
# 4860                      0.0                    0.0
# 3867                      0.0                    0.0
# 3810                      0.0                    0.0
#
#       remainder__SeniorCitizen  remainder__tenure  remainder__MonthlyCharges  \
# 3738                       0.0               35.0                      49.20
# 3151                       0.0               15.0                      75.10
# 4860                       0.0               13.0                      40.55
# 3867                       0.0               26.0                      73.50
# 3810                       0.0                1.0                      44.55
#
#       remainder__TotalCharges  remainder__num_services
# 3738                  1701.65                      3.0
# 3151                  1151.55                      1.0
# 4860                   590.35                      3.0
# 3867                  1905.70                      4.0
# 3810                    44.55                      0.0
#
# [5 rows x 51 columns]

# %%
param_grid = {
    'max_depth': [3, 5, 10, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'criterion': ['gini', 'entropy']
}

from sklearn.model_selection import GridSearchCV

model = DecisionTreeClassifier(
    random_state=42, class_weight='balanced'
)

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='roc_auc',   # VERY important for churn
    cv=5,
    n_jobs=-1,
    verbose=1
)

# %%
grid_search.fit(X_train_processed, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best CV ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# Best parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# Best CV ROC-AUC: 0.8274107735292514

# %%
best_dt = grid_search.best_estimator_
y_pred = best_dt.predict(X_test_processed)
y_pred_proba = best_dt.predict_proba(X_test_processed)[:, 1]

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_pred_proba))
# Out:
# Accuracy: 0.7544357700496807
# Precision: 0.5262172284644194
# Recall: 0.7513368983957219
# F1: 0.6189427312775331
# ROC AUC: 0.837468030690537

# %%
y_probs = best_dt.predict_proba(X_test_processed)[:,1]
y_pred = (y_probs > 0.40).astype(int)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_probs))
# Out:
# Accuracy: 0.7210787792760823
# Precision: 0.48588410104011887
# Recall: 0.8743315508021391
# F1: 0.6246418338108882
# ROC AUC: 0.837468030690537

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

y_proba = best_dt.predict_proba(X_test_processed)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = roc_auc_score(y_test, y_proba)

plt.figure(figsize=(8,6))

plt.plot(fpr, tpr, linewidth=2, label=f'ROC Curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')  

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve of Decision Tree')
plt.legend()
plt.grid()

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix – Tuned Decision Tree")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train_processed.columns,
    'Importance': best_dt.feature_importances_
}).sort_values(by='Importance', ascending=False)

feature_importance.head(10)
# Out:
#                                 Feature  Importance
# 32         cat__Contract_Month-to-month    0.557165
# 47                    remainder__tenure    0.119518
# 12     cat__InternetService_Fiber optic    0.104072
# 48            remainder__MonthlyCharges    0.086847
# 33               cat__Contract_One year    0.028961
# 49              remainder__TotalCharges    0.026689
# 23                  cat__TechSupport_No    0.021767
# 39  cat__PaymentMethod_Electronic check    0.020875
# 17                 cat__OnlineBackup_No    0.007069
# 14               cat__OnlineSecurity_No    0.005737

# %%
import joblib

joblib.dump(best_dt, "../models/decision_tree_tuned.pkl")
# Out:
# ['../models/decision_tree_tuned.pkl']
